# %%
import sys
sys.path.append('..')
from jaewook_header import *
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
IN='../../input/제욱new/'
OUT='../../input/masks/'

# %%
for g in glob(IN+'*.png'):
    p,f=split(g)
    img=imread(g)
    imsave(OUT+f.replace('-','_'),img)

# %%
ls "../../input/masks"
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: D021-C282
#
#  C:\Users\snu\Dropbox\input\masks 디렉터리
#
# 2018-11-30  오전 05:30    <DIR>          .
# 2018-11-30  오전 05:30    <DIR>          ..
# 2018-11-30  오전 05:30             7,042 data1_L_001.png
# 2018-11-30  오전 05:30             7,479 data1_L_002.png
# 2018-11-30  오전 05:30             7,763 data1_L_003.png
# 2018-11-30  오전 05:30             6,870 data1_L_004.png
# 2018-11-30  오전 05:30             8,004 data1_L_005.png
# 2018-11-30  오전 05:30             7,168 data1_L_006.png
# 2018-11-30  오전 05:30             7,764 data1_L_007.png
# 2018-11-30  오전 05:30             6,971 data1_L_008.png
# 2018-11-30  오전 05:30             7,654 data1_L_009.png
# 2018-11-30  오전 05:30             8,442 data1_L_010.png
# 2018-11-30  오전 05:30             6,796 data1_L_011.png
# 2018-11-30  오전 05:30             7,972 data1_L_012.png
# 2018-11-30  오전 05:30             8,475 data1_L_013.png
# 2018-11-30  오전 05:30             7,700 data1_L_014.png
# ...
